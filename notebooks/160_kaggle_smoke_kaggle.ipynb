# %%
import os, time
with open('/kaggle/working/hello.txt', 'w') as f:
    f.write(f'hello world {time.time()}\n')
print('wrote hello.txt')
print('cwd:', os.getcwd())
print('listdir /kaggle/working:', os.listdir('/kaggle/working'))
