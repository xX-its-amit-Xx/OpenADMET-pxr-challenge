# %%
import torch, glob, os
print('cuda', torch.cuda.is_available())
print('device count', torch.cuda.device_count())
hits = glob.glob('/kaggle/input/**/found_features.parquet', recursive=True)
print('found_features hits:', hits)
import pandas as pd
if hits:
    print('shape', pd.read_parquet(hits[0]).shape)
print('SMOKE OK')
